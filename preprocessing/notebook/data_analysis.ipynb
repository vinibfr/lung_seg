# %% [markdown]
# # libraries

# %%
# %pip install pylidc
# Out:
# Requirement already satisfied: pylidc in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (0.2.3)
# Requirement already satisfied: sqlalchemy>=1.1.5 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (2.0.23)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (1.24.3)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (1.10.1)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (3.7.1)
# Requirement already satisfied: pydicom>=1.0.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (2.4.3)
# Requirement already satisfied: scikit-image>=0.13 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from pylidc) (0.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.0.0->pylidc) (2.8.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.13->pylidc) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.13->pylidc) (2.32.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.13->pylidc) (2023.9.26)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.13->pylidc) (0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.1.5->pylidc) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.1.5->pylidc) (3.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\vinic\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pylidc) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # import

# %%
import pylidc as pl
import numpy as np
import matplotlib.pyplot as plt
from pylidc.utils import consensus
from skimage.measure import find_contours

# %% [markdown]
# # code

# %%
path = 'E:\lung_nodule\preprocessing\datasets\LIDC-IDRI\LIDC-IDRI-0030'
f = open('.pylidcrc', 'w')
f.write(f'[dicom]\npath = {path}\n\n')
f.close()

# %%
plt.set_cmap('gray')

# %%
pid = 'LIDC-IDRI-0001'
scan = pl.query(pl.Scan).filter(pl.Scan.patient_id == pid).first()

# %%
vol = scan.to_volume()
print(vol.shape) # (dim, dim, depth)

plt.figure(figsize=(5, 5))
plt.imshow(vol[:,:,0])
plt.show() # show the first-level slice
# Out:
# Loading dicom files ... This may take a moment.
# (512, 512, 133)

# %%
pid = 'LIDC-IDRI-0001'
annot = pl.query(pl.Annotation).filter(pl.Scan.patient_id == pid).first()
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_35612\4051012190.py:2: SAWarning: SELECT statement has a cartesian product between FROM element(s) "scans" and FROM element "annotations".  Apply join condition(s) between each element to resolve.
#   annot = pl.query(pl.Annotation).filter(pl.Scan.patient_id == pid).first()

# %%
annot.print_formatted_feature_table()
# Out:
# Feature              Meaning                    #
# -                    -                          -
# Subtlety           | Obvious                  | 5
# Internalstructure  | Soft Tissue              | 1
# Calcification      | Absent                   | 6
# Sphericity         | Ovoid                    | 3
# Margin             | Near Sharp               | 4
# Lobulation         | No Lobulation            | 1
# Spiculation        | No Spiculation           | 1
# Texture            | Solid                    | 5
# Malignancy         | Indeterminate            | 3

# %%
padding = [(10, 10), (25, 25), (0, 0)]

masks = annot.boolean_mask(pad = padding)
bbox = annot.bbox(pad = padding)
relevant_vol = vol[bbox]

for region in range(masks.shape[2]):
    
    plt.figure(figsize=(10, 5), dpi=400)
    plt.subplot(1, 2, 1)
    plt.imshow(relevant_vol[:,:,region])
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(masks[:,:,region])
    plt.axis('off')
    plt.show()
    plt.close()

# %%
scan = pl.query(pl.Scan).filter(pl.Scan.patient_id == 'LIDC-IDRI-0001').first()
vol = scan.to_volume()

nods = scan.cluster_annotations()
anns = nods[0]

cmask,cbbox,masks = consensus(anns, clevel=0.5,
                              pad=[(20,20), (20,20), (0,0)])
k = int(0.5*(cbbox[2].stop - cbbox[2].start))

# Set up the plot.
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.imshow(vol[cbbox][:,:,k], cmap=plt.cm.gray, alpha=0.5)

# Plot the annotation contours for the kth slice.
colors = ['r', 'g', 'b', 'y']
for j in range(len(masks)):
    for c in find_contours(masks[j][:,:,k].astype(float), 0.5):
        label = "Annotation %d" % (j+1)
        plt.plot(c[:,1], c[:,0], colors[j], label=label)

# Plot the 50% consensus contour for the kth slice.
for c in find_contours(cmask[:,:,k].astype(float), 0.5):
    plt.plot(c[:,1], c[:,0], '--k', label='50% Consensus')

ax.axis('off')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Loading dicom files ... This may take a moment.

# %% [markdown]
# # Create label for training in future

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
meta = pd.read_csv('../data/Metameta_info.csv')

# %%
clean_meta = meta[meta['malignancy'].isin([1,2])]
meta = meta[meta['malignancy'].isin([4, 5])]

# %%
meta.head()
# Out:
#    patient_id  nodule_no  slice_no       original_image           mask_image
# 0           1          0         0  0001_NI000_slice000  0001_MA000_slice000  \
# 1           1          0         1  0001_NI000_slice001  0001_MA000_slice001
# 2           1          0         2  0001_NI000_slice002  0001_MA000_slice002
# 3           1          0         3  0001_NI000_slice003  0001_MA000_slice003
# 4           1          0         4  0001_NI000_slice004  0001_MA000_slice004
#
#    malignancy is_cancer  is_clean
# 0           5      True     False
# 1           5      True     False
# 2           5      True     False
# 3           5      True     False
# 4           5      True     False

# %%
# NI= Nodule Image, MA = Mask Original , CN = Clean Nodule , CM = Clean Mask

# %%
def is_nodule(row):
    if row[5:7] =='NI':        
        return True
    else:
        return False

# %%
meta['is_nodule']= meta['original_image'].apply(lambda row: is_nodule(row))

# %%
meta['is_nodule']= meta['original_image'].apply(lambda row: is_nodule(row))
clean_meta['is_nodule']= clean_meta['original_image'].apply(lambda row: is_nodule(row))

# %%
meta[meta['is_cancer']==False]
# Out:
# Empty DataFrame
# Columns: [patient_id, nodule_no, slice_no, original_image, mask_image, malignancy, is_cancer, is_clean]
# Index: []

# %%
# Lets separate Clean meta and meta data
clean_meta = meta[meta['is_nodule']==False]
clean_meta.reset_index(inplace=True)
meta = meta[meta['is_nodule']==True]
meta.reset_index(inplace=True)

# %%
# Lets separate Clean meta and meta data
clean_meta = meta[meta['is_nodule']==False]
clean_meta.reset_index(inplace=True)
meta = meta[meta['is_nodule']==True]
meta.reset_index(inplace=True)

# %%
clean_meta.head(2)
# Out:
#     patient_id  nodule_no  slice_no       original_image           mask_image
# 36           3          0         0  0003_NI000_slice000  0003_MA000_slice000  \
# 37           3          0         1  0003_NI000_slice001  0003_MA000_slice001
#
#     malignancy is_cancer  is_clean  is_nodule
# 36           2     False     False       True
# 37           2     False     False       True

# %%
meta.head(2)
# Out:
#    patient_id  nodule_no  slice_no       original_image           mask_image
# 0           1          0         0  0001_NI000_slice000  0001_MA000_slice000  \
# 1           1          0         1  0001_NI000_slice001  0001_MA000_slice001
#
#    malignancy is_cancer  is_clean  is_nodule
# 0           5      True     False       True
# 1           5      True     False       True

# %%
def is_train(row,train,val,test):
    if row in train:
        return 'Train'
    elif row in val:
        return 'Validation'
    else:
        return 'Test'

# %%
clean_patient_id = list(np.unique(clean_meta['patient_id']))
meta_patient_id = list(np.unique(meta['patient_id']))

# %%
def create_label_segmentation(meta):
    patient_id = list(np.unique(meta['patient_id']))
    train_patient , test_patient = train_test_split(patient_id,test_size= 0.25)
    train_patient, val_patient = train_test_split(train_patient,test_size= 0.25)
    print(len(train_patient),len(val_patient),len(test_patient))
    
    meta['data_split']= meta['patient_id'].apply(lambda row : is_train(row,train_patient,val_patient,test_patient))
    
    return meta

# %%
# We need to train/test split independently for clean_meta, meta
meta = create_label_segmentation(meta)
clean_meta = create_label_segmentation(clean_meta)
# Out:
# 221 74 99
# 255 85 114

# %%
meta.head(10)
# Out:
#    patient_id  nodule_no  slice_no       original_image           mask_image
# 0           1          0         0  0001_NI000_slice000  0001_MA000_slice000  \
# 1           1          0         1  0001_NI000_slice001  0001_MA000_slice001
# 2           1          0         2  0001_NI000_slice002  0001_MA000_slice002
# 3           1          0         3  0001_NI000_slice003  0001_MA000_slice003
# 4           1          0         4  0001_NI000_slice004  0001_MA000_slice004
# 5           1          0         5  0001_NI000_slice005  0001_MA000_slice005
# 6           1          0         6  0001_NI000_slice006  0001_MA000_slice006
# 7           1          0         7  0001_NI000_slice007  0001_MA000_slice007
# 8           2          0         0  0002_NI000_slice000  0002_MA000_slice000
# 9           2          0         1  0002_NI000_slice001  0002_MA000_slice001
#
#    malignancy is_cancer  is_clean  is_nodule data_split
# 0           5      True     False       True       Test
# 1           5      True     False       True       Test
# 2           5      True     False       True       Test
# 3           5      True     False       True       Test
# 4           5      True     False       True       Test
# 5           5      True     False       True       Test
# 6           5      True     False       True       Test
# 7           5      True     False       True       Test
# 8           5      True     False       True      Train
# 9           5      True     False       True      Train

# %%
clean_meta.head()
# Out:
#     patient_id  nodule_no  slice_no       original_image           mask_image
# 36           3          0         0  0003_NI000_slice000  0003_MA000_slice000  \
# 37           3          0         1  0003_NI000_slice001  0003_MA000_slice001
# 38           3          0         2  0003_NI000_slice002  0003_MA000_slice002
# 39           3          0         3  0003_NI000_slice003  0003_MA000_slice003
# 40           3          0         4  0003_NI000_slice004  0003_MA000_slice004
#
#     malignancy is_cancer  is_clean  is_nodule data_split
# 36           2     False     False       True       Test
# 37           2     False     False       True       Test
# 38           2     False     False       True       Test
# 39           2     False     False       True       Test
# 40           2     False     False       True       Test

# %%
# Clean Meta only stores meta information of patients without nodules.

# %%
meta.to_csv('../data/meta_sep.csv')
clean_meta.to_csv('../data/clean_meta_sep.csv')

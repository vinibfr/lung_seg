# %% [markdown]
# # Create label for training in future

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
image = np.load('0046_NI000_slice000.npy')
mask = np.load('0046_MA000_slice000.npy')

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(mask)
plt.show()
